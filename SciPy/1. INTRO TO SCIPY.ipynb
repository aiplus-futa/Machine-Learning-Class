# %% [markdown]
# # SCIPY
#
# #### Python library for scientific and mathematical problems
#
# scipy is the core package for scientific routines in Python; it is meant to operate efficiently on numpy arrays, so that numpy and scipy work hand in hand.
#
# The scipy package contains various toolboxes dedicated to common issues in scientific computing. Its different submodules correspond to different applications, such as interpolation, integration, optimization, image processing, statistics, special functions, etc.

# %% [markdown]
# ## Sub-Packages
# Scipy have subpackages for scientific computations
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  I will be Concentrating on special, interpolate, integrate, optimize, linalg, io, stats subpackages in the next notebook.
#
#  I will like to explain somethings on the packages i wont be concentrating on.
#
#  ### Constants
#  This subpackage contains different constants in science you can check them by:
#
#  from scipy import constants
#
#  help(constants)
#
#
#  ### ndimage
#  This subpackage help in image processing.It will be in fact useful in data augumentation in image classification tasks
